# %% [markdown]
# #**Import Libraries**

# %%
# !pip install torch_lr_finder --upgrade

# %%
from __future__ import print_function
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
import warnings
warnings.filterwarnings("ignore")
# !pip install summary
from torchsummary import summary

# %% [markdown]
# #**Data Download and Transforms**

# %%
from utils import DataDownloader
data_downloader = DataDownloader()
train = data_downloader.download_train_data()
test = data_downloader.download_test_data()
# Out:
# Files already downloaded and verified

# %% [markdown]
# #**Data Loaders**

# %%
from utils import TrainTestDataloaders
train_test_dataloaders = TrainTestDataloaders()
train_loader = train_test_dataloaders.get_train_dataloader(train)
test_loader = train_test_dataloaders.get_train_dataloader(test)

# %% [markdown]
# #**Showing some sample images**

# %%
import warnings
from utils import SampleData
warnings.filterwarnings("ignore")
sample_data = SampleData()
sample_data.show_sample_images(train_loader, train.classes)

# %% [markdown]
# ##**Model**

# %%
use_cuda = torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")
print(device)
# Out:
# cuda

# %%
from custom_resnet import Custom_Resnet
model = Custom_Resnet().to(device)
summary(model, input_size = (3,32,32))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1           [-1, 64, 32, 32]           1,728
#               ReLU-2           [-1, 64, 32, 32]               0
#        BatchNorm2d-3           [-1, 64, 32, 32]             128
#            Dropout-4           [-1, 64, 32, 32]               0
#             Conv2d-5          [-1, 128, 32, 32]          73,728
#          MaxPool2d-6          [-1, 128, 16, 16]               0
#               ReLU-7          [-1, 128, 16, 16]               0
#        BatchNorm2d-8          [-1, 128, 16, 16]             256
#            Dropout-9          [-1, 128, 16, 16]               0
#            Conv2d-10          [-1, 128, 16, 16]         147,456
#              ReLU-11          [-1, 128, 16, 16]               0
#       BatchNorm2d-12          [-1, 128, 16, 16]             256
#           Dropout-13          [-1, 128, 16, 16]               0
# ...

# %% [markdown]
# #**Train and Test Model**

# %%
from train_test_models import Train_Test_With_LR_Scheduler
train_test_obj = Train_Test_With_LR_Scheduler()
lr = 0.04
weight_decay = 1e-4
train_losses, test_losses, train_acc, test_acc = train_test_obj.train_and_test_model(model, device, 24, train_loader, test_loader, lr, weight_decay)
# Out:
#   0%|          | 0/200 [00:00<?, ?it/s]
# Stopping early, the loss has diverged
# Learning rate search finished. See the graph with {finder_name}.plot()
# LR suggestion: steepest gradient
# Suggested LR: 6.78E-02
# EPOCH: 0
# loss=1.3519388437271118 Batch_id=97 Accuracy=44.72: 100%|██████████| 98/98 [00:21<00:00,  4.47it/s]
#  Test set: Average loss: 1.1874, Accuracy: 5800/10000 (58.00%)
#
# EPOCH: 1
# loss=1.1138375997543335 Batch_id=97 Accuracy=59.53: 100%|██████████| 98/98 [00:21<00:00,  4.55it/s]
#  Test set: Average loss: 0.9394, Accuracy: 6695/10000 (66.95%)
#
# EPOCH: 2
# loss=0.8656499981880188 Batch_id=97 Accuracy=66.91: 100%|██████████| 98/98 [00:21<00:00,  4.60it/s]
#  Test set: Average loss: 0.7583, Accuracy: 7312/10000 (73.12%)
#
# EPOCH: 3
# loss=0.8536176085472107 Batch_id=97 Accuracy=72.28: 100%|██████████| 98/98 [00:21<00:00,  4.55it/s]
#  Test set: Average loss: 0.6782, Accuracy: 7658/10000 (76.58%)
#
# EPOCH: 4
# ...

# %% [markdown]
# # **Visualise train and test performance**

# %%
from train_test_models import ResultVisualisation
result_visualisation_obj = ResultVisualisation()
result_visualisation_obj.plot_accuracy_and_loss(train_losses, test_losses, train_acc, test_acc)

# %% [markdown]
# # **Showing some misclassified Images**

# %%
from utils import SampleData
sample_data = SampleData()
sample_data.show_misclassified_images(train_test_obj.misclassified_images, train_test_obj.original_labels, train_test_obj.predicted_labels, train.classes)
# Out:
# 25 25 25
